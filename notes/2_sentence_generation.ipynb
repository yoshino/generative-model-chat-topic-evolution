# %% [markdown]
# # 文章生成

# %%
# 遺伝形質
PN1 = [
  "ありがたさ", "豪華さ", "リフレッシュ", "安心", "意匠性","逸材","栄光","温もり","結婚","陽気","遊び心","優しさ", "冒険心", "華やかさ","想像力",
  "曖昧さ","いざこざ","いたずら","うつ病","哀れみ","威圧感","陰口","過疎","絵空事","寒さ","汗だく","危険","気まずさ","偽善","恐ろしさ"
]

# %%
from llama_cpp import Llama

llm = Llama(
    model_path="../models/ELYZA-japanese-Llama-2-7b-instruct-q5_K_M.gguf", 
    device="mps", 
    n_ctx=3000,
    verbose=False
)
# Out:
# llama_model_loader: loaded meta data with 21 key-value pairs and 291 tensors from ../models/ELYZA-japanese-Llama-2-7b-instruct-q5_K_M.gguf (version GGUF V2 (latest))
# llama_model_loader: - tensor    0:                token_embd.weight q5_K     [  4096, 32000,     1,     1 ]
# llama_model_loader: - tensor    1:              blk.0.attn_q.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    2:              blk.0.attn_k.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    3:              blk.0.attn_v.weight q6_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    4:         blk.0.attn_output.weight q5_K     [  4096,  4096,     1,     1 ]
# llama_model_loader: - tensor    5:            blk.0.ffn_gate.weight q5_K     [  4096, 11008,     1,     1 ]
# llama_model_loader: - tensor    6:            blk.0.ffn_down.weight q6_K     [ 11008,  4096,     1,     1 ]
# ...

# %%
import random

class Agent:
    def __init__(self, gene, cultures=[]):
      self.round = 1
      self.gene = gene
      self.cultures = cultures
      self.histories = []
    
    def talk(self):
      prompt = self.__prompt()
      self.histories.append(prompt)

      response = llm(prompt, max_tokens=500)
      return prompt + response["choices"][0]['text']

    def __prompt(self):
      # 確率5%で直近のpromptを返す
      if random.random() < 0.05 and len(self.histories) > 0:
        return self.histories[-1]

      if len(self.cultures) == 0:
        return "{}は".format(self.gene)
      else:
        culture = random.choice(self.cultures)
        return "{}と{}は".format(self.gene, culture)

# %%
gene = random.choice(PN1)
print("gene: {}".format(gene))

agent = Agent(gene)
agent.talk()
# Out:
# gene: 優しさ
# '優しさは男性にとってもたらすだけでなく、女性から求められることも多いもの。\nそのため、彼女の前では絶えず優しさを見せつけたいと考える男性が少なくありません。しかし、どんなときに優しさを発揮すればいいのでしょうか？今回は女性が求める優しさの５つのパターンをご紹介します。\n\n「あの子、泣きやまない」と友達の結婚式で困っていた若い女性が、大将に助けを求めました。 お店の方々も、その女性のために料理を取りに行ってくれ、泣きやむことができたそうです。\nなんでも相談できる居酒屋って素敵だなぁ。\n#大将 #bar #お店 #焼鳥 #居酒屋 #相談受けます https://t.co/bw5Y69xVdI pic.twitter.com/nWc4a1iFyP\n「あの子、泣きやまない」と友達の結婚式で困っていた若い女性が、大将に助けを求めました。 お店の方々も、その女性のために料理取りに行ってくれ、泣きやむことができたそうです。\nなんでも相談できる居酒屋って素敵だなぁ。 #大将 #bar #お店 #焼鳥 #居酒屋 #相談受けます https://t.co/bw5Y6'

# %%
agent_with_culture = Agent(gene, cultures=["日本"])
agent_with_culture.talk()
# Out:
# '優しさと日本は似ていると思う。\n優しく人を包み込むような気持ちが、「和」や「おもてなし」に表れているのではないだろうか。それは同時に、世界に羽ばたく力としても働くのだと思う。日本人が持つ心の優しさを、これからも大切に育んでいきたい。\nまた「強い日本」を取り戻すためには何が必要だろうか。経済や文化の面で世界と戦って勝利し、その力で困難な時代を切り開くことも大切だろう。それは「強さ」によるものだと私たちは思わずにいられない。\nその一方で、日本人が持つ優しさや温かさを世界に伝えていくことも「強さ」の源泉になる。大切に育んだ心を背景に、新たな時代へ向けて進んでいきたい。\n(野村証券チーフマーケットエコノミスト 西潟弘一氏)■12日\n日本の将来を左右する重要な選択が、急速に近づいてきた。今週は東京電力福島第1原子力発電所の事故の影響で、政府が緊急事態宣言を出した。その後、「安全神話」の脆さに直面して以来、国民は原発に対する警戒感を強めた。それは政治にも影響を与え、'
